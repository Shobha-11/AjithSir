# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,6])
y=np.array([0,250])
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,6,8])
y=np.array([3,8,1,10])
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,6,8])
y=np.array([3,8,1,10])
x_ticks=np.arange(1,10,0.5)
plt.xticks(x_ticks)
y_ticks=np.arange(1,11,1)
plt.yticks(y_ticks)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,8])
y=np.array([3,10])
plt.plot(x,y,'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,6,8])
y=np.array([3,8,1,10])
plt.plot(x,y,'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, marker='o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, marker='s')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, marker='+')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, marker='D')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, marker='d')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, marker='2')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, marker='s', ms=10)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, marker='o', ms=10, mec='r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, marker='o', ms=15, mfc='r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, marker='o', ms=15, mfc='#F56660', mec='#F56660')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, linestyle="dotted", marker='o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, linestyle="dashed", marker='o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, ls=":", marker='o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, ls="--", marker='o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, color='r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, color='#000000')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([3,8,1,10])
plt.plot(y, color='#000000', linewidth='5')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y1=np.array([3,8,1,10])
y2=np.array([6,2,5,3])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x1=np.array([2,7,2,9])
y1=np.array([3,8,1,10])
x2=np.array([5,4,3,2])
y2=np.array([6,2,5,3])
plt.plot(x1,y1,x2,y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80, 85, 90, 95, 100, 105, 110, 120, 125])
y=np.array([240, 250, 260, 270, 280, 300, 310, 320, 330])
plt.plot(x,y)
plt.xlabel("Pulse")
plt.ylabel("Calorie")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80, 85, 90, 95, 100, 105, 110, 120, 125])
y=np.array([240, 250, 260, 270, 280, 300, 310, 320, 330])
plt.plot(x,y)
plt.title("Sport Watch")
plt.xlabel("Pulse")
plt.ylabel("Calorie")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80, 85, 90, 95, 100, 105, 110, 120, 125])
y=np.array([240, 250, 260, 270, 280, 300, 310, 320, 330])
font1={'family':'serif', 'color':'blue', 'size':20}
font2={'family':'serif', 'color':'red', 'size':20}
plt.plot(x,y)
plt.title("Sport Watch", fontdict=font1)
plt.xlabel("Pulse", fontdict=font2)
plt.ylabel("Calorie", fontdict=font1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80, 85, 90, 95, 100, 105, 110, 120, 125])
y=np.array([240, 250, 260, 270, 280, 300, 310, 320, 330])
font1={'family':'serif', 'color':'blue', 'size':20}
font2={'family':'serif', 'color':'red', 'size':20}
plt.plot(x,y)
plt.title("Sport Watch",loc='left', fontdict=font1)
plt.xlabel("Pulse", fontdict=font2)
plt.ylabel("Calorie", fontdict=font1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80, 85, 90, 95, 100, 105, 110, 120, 125])
y=np.array([240, 250, 260, 270, 280, 300, 310, 320, 330])
font1={'family':'serif', 'color':'blue', 'size':20}
font2={'family':'serif', 'color':'red', 'size':20}
plt.plot(x,y)
plt.title("Sport Watch",loc='left', fontdict=font1)
plt.xlabel("Pulse", fontdict=font2)
plt.ylabel("Calorie", fontdict=font1)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80, 85, 90, 95, 100, 105, 110, 120, 125])
y=np.array([240, 250, 260, 270, 280, 300, 310, 320, 330])
font1={'family':'serif', 'color':'blue', 'size':20}
font2={'family':'serif', 'color':'red', 'size':20}
plt.plot(x,y)
plt.title("Sport Watch",loc='left', fontdict=font1)
plt.xlabel("Pulse", fontdict=font2)
plt.ylabel("Calorie", fontdict=font1)
plt.grid(axis='x')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80, 85, 90, 95, 100, 105, 110, 120, 125])
y=np.array([240, 250, 260, 270, 280, 300, 310, 320, 330])
font1={'family':'serif', 'color':'blue', 'size':20}
font2={'family':'serif', 'color':'red', 'size':20}
plt.plot(x,y)
plt.title("Sport Watch",loc='left', fontdict=font1)
plt.xlabel("Pulse", fontdict=font2)
plt.ylabel("Calorie", fontdict=font1)
plt.grid(axis='y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80, 85, 90, 95, 100, 105, 110, 120, 125])
y=np.array([240, 250, 260, 270, 280, 300, 310, 320, 330])
font1={'family':'serif', 'color':'blue', 'size':20}
font2={'family':'serif', 'color':'red', 'size':20}
plt.plot(x,y)
plt.title("Sport Watch",loc='left', fontdict=font1)
plt.xlabel("Pulse", fontdict=font2)
plt.ylabel("Calorie", fontdict=font1)
plt.grid(color='red', linestyle='--', linewidth=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot1
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
#plot2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot1
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,1,1)
plt.plot(x,y)
#plot2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,1,2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot1
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("sales")
#plot2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("profit")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot1
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("sales")
#plot2
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("profit")
plt.suptitle("My Shop")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot1
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,112,86,103,87,94,88,77,85,86])
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
#plot1
x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y=np.array([99,86,87,88,112,86,103,87,94,88,77,85,86])
plt.scatter(x,y, color="red")
#plot2
x=np.array([6,8,9,6,3,16,3,10,5,12,13,6,4])
y=np.array([100,105,84,89,113,80,109,89,95,82,79,88,87])
plt.scatter(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.barh(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["A","B","C","D"])
y=np.array([3,8,1,10])
plt.barh(x,y, color="red")
plt.show()
